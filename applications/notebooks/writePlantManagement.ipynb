# %%
#libraries
import numpy as np
from netCDF4 import Dataset
import subprocess
from pathlib import Path


from scripts.PlantMgmtWriter import PlantMgmtWriter


PlantMgmtWriter(in_json='../../example_input/pftMgmtExample.json',out_nc='grass_all_mgmt2.nc')
# Out:
# here1
# Wrote NetCDF file: grass_all_mgmt2.nc
